# %%
import numpy as np
import pandas as pd

# %%
data=np.loadtxt('0000000000002417_training_boston_x_y_train.csv',delimiter=',')

# %%
##form of data
pd.DataFrame(data)
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#            7         8         9         10        11        12    13
# ...

# %%
x=data[:,:13]
y=data[:,13]

# %%
##code gradient descent for n features and retrieve the ,i's and c
def gd(x,y):
    params=np.zeros(14)
    lr=0.1
    for i in range(1000):
        support=np.zeros(14)
        for j in range(len(x)):
            xi=x[j,:]
            xi=np.append(xi,1)
            yi=y[j]
            s= (params * xi).sum()
            for k in range(14):
                support[k]=support[k]+ ((-2/len(x)) * (yi-s) * xi[k] )
        ypred=[]
        for j in range(len(x)):
            v=x[j,:]
            v=np.append(v,1)
            ypred.append((v*params).sum())
        ypred=np.array(ypred)
        c=(1/len(x)) * sum([val**2 for val in (y-ypred)])
        print("iteration{},cost{}".format(i+1,c))
        params=params-(lr*support)
    return params

# %%
params=gd(x,y)
# Out:
# iteration1,cost599.1222691292877
# iteration2,cost374.24035597919675
# iteration3,cost245.379096560799
# iteration4,cost165.1061419217367
# iteration5,cost114.49508621191679
# iteration6,cost82.43432664281792
# iteration7,cost62.04170468831088
# iteration8,cost49.01547466604823
# iteration9,cost40.65519326019774
# iteration10,cost35.25972835067589
# iteration11,cost31.754121492629714
# iteration12,cost29.457161634001743
# iteration13,cost27.93600702214454
# iteration14,cost26.914922412896345
# iteration15,cost26.21780295198016
# iteration16,cost25.73187282296312
# iteration17,cost25.384699117718043
# iteration18,cost25.129603525591058
# iteration19,cost24.936384410518805
# iteration20,cost24.785404792037344
# iteration21,cost24.663818221907494
# iteration22,cost24.56315514362142
# iteration23,cost24.477776518190076
# iteration24,cost24.403881200700205
# iteration25,cost24.3388674348962
# iteration26,cost24.280921148348426
# iteration27,cost24.228749732407827
# ...

# %%
params
# Out:
# array([-9.38080610e-01,  7.41033999e-01,  1.16903020e-02,  7.80873861e-01,
#        -2.17455732e+00,  2.35429667e+00,  1.23337955e-01, -2.95232364e+00,
#         2.53296549e+00, -1.70290056e+00, -2.25151951e+00,  5.88354232e-01,
#        -4.26368148e+00,  2.26772333e+01])

# %%
## predict y
def predict(x,params):
    ypredict=[]
    for i in range(len(x)):
        entry=x[i]
        entry=np.append(entry,1)
        ypredict.append((entry*params).sum())
    return ypredict

# %%
datatest=np.loadtxt('0000000000002417_test_boston_x_test.csv',delimiter=',')
res=predict(datatest,params)

# %%
res=pd.DataFrame(res)
res.to_csv('predict.csv',header=False,index=False)

# %%
##score
def score(yog,ypred):
    u=((yog-ypred)**2).sum()
    v=(yog-(yog.mean())**2).sum()
    return 1-(u/v)
