# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
data=np.loadtxt('0000000000002419_training_ccpp_x_y_train.csv',delimiter=',')

# %%
##form of data
pd.DataFrame(data)
# Out:
#           0      1        2      3       4
# 0      8.58  38.38  1021.03  84.37  482.26
# 1     21.79  58.20  1017.21  66.74  446.94
# 2     16.64  48.92  1011.55  78.76  452.56
# 3     31.38  71.32  1009.17  60.42  433.44
# 4      9.20  40.03  1017.05  92.46  480.38
# ...     ...    ...      ...    ...     ...
# 7171   9.32  37.73  1022.14  79.49  477.91
# 7172  11.20  41.38  1021.65  61.89  476.87
# 7173  29.80  69.34  1009.36  64.74  437.65
# 7174  16.37  54.30  1017.94  63.63  459.97
# 7175  30.11  62.04  1010.69  47.96  444.42
#
# [7176 rows x 5 columns]

# %%
x=data[:,:4]
y=data[:,4]

# %%
##code gradient descent for n features and retrieve the ,i's and c
def gd(x,y):
    params=np.zeros(5)
    lr=0.0000001
    for i in range(100):
        support=np.zeros(5)
        for j in range(len(x)):
            xi=x[j,:]
            xi=np.append(xi,1)
            yi=y[j]
            s= (params * xi).sum()
            for k in range(5):
                support[k]=support[k]+ ((-2/len(x)) * (yi-s) * xi[k] )
        ypred=[]
        for j in range(len(x)):
            v=x[j,:]
            v=np.append(v,1)
            ypred.append((v*params).sum())
        ypred=np.array(ypred)
        c=(1/len(x)) * sum([val**2 for val in (y-ypred)])
        print("iteration{},cost{}".format(i+1,c))
        params=params-(lr*support)
    return params

# %%
params=gd(x,y)
# Out:
# iteration1,cost206801.35285512786
# iteration2,cost130113.76218593332
# iteration3,cost81899.50056090437
# iteration4,cost51586.705141741855
# iteration5,cost32528.740228401664
# iteration6,cost20546.79960623363
# iteration7,cost13013.626093159965
# iteration8,cost8277.436872216764
# iteration9,cost5299.739597459209
# iteration10,cost3427.623764243273
# iteration11,cost2250.5980206208783
# iteration12,cost1510.5823558928498
# iteration13,cost1045.3192910491614
# iteration14,cost752.7959293010408
# iteration15,cost568.8757440937269
# iteration16,cost453.23546093932646
# iteration17,cost380.5234346401876
# iteration18,cost334.800832787696
# iteration19,cost306.04675233708264
# iteration20,cost287.960951510363
# iteration21,cost276.5824054094679
# iteration22,cost269.4207781399647
# iteration23,cost264.9103706651568
# iteration24,cost262.066812370992
# iteration25,cost260.2712196258446
# iteration26,cost259.13449411241504
# iteration27,cost258.41200583435096
# ...

# %%
params
# Out:
# array([6.36192283e-03, 2.02197886e-02, 4.44855399e-01, 3.39074788e-02,
#        4.38270335e-04])

# %%
## predict y
def predict(x,params):
    ypredict=[]
    for i in range(len(x)):
        entry=x[i]
        entry=np.append(entry,1)
        ypredict.append((entry*params).sum())
    return ypredict

# %%
datatest=np.loadtxt('0000000000002419_test_ccpp_x_test.csv',delimiter=',')
res=predict(datatest,params)

# %%
np.savetxt('predict2.csv',res,fmt="%.4f")
